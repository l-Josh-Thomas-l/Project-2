# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('default')

# %%
data ="../data/fertilizer-use-in-kg-per-hectare-of-arable-land.csv"

# %%
data_df = pd.read_csv(data, encoding="ISO-8859-1")

data_df.head(5)
# Out:
#        Country Code  Year  \
# 0  Afghanistan  AFG  1961
# 1  Afghanistan  AFG  1962
# 2  Afghanistan  AFG  1963
# 3  Afghanistan  AFG  1964
# 4  Afghanistan  AFG  1965
#
#    Fertilizer consumption (kilograms per hectare of arable land)
# 0                                           0.143791
# 1                                           0.142857
# 2                                           0.141935
# 3                                           0.141026
# 4                                           0.141026

# %%
data_df = data_df.rename(columns={'Entity':'Country/Continent'})
data_df=data_df.drop('Code',1);

data_df
# Out:
# C:\Users\marty\AppData\Local\Temp/ipykernel_18776/2234217904.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   data_df=data_df.drop('Code',1);
#           Country  Year  \
# 0     Afghanistan  1961
# 1     Afghanistan  1962
# 2     Afghanistan  1963
# 3     Afghanistan  1964
# 4     Afghanistan  1965
# ...           ...   ...
# 8830     Zimbabwe  2014
# 8831     Zimbabwe  2015
# 8832     Zimbabwe  2016
# 8833     Zimbabwe  2017
# 8834     Zimbabwe  2018
#
#       Fertilizer consumption (kilograms per hectare of arable land)
# 0                                              0.143791
# 1                                              0.142857
# 2                                              0.141935
# 3                                              0.141026
# 4                                              0.141026
# ...                                                 ...
# ...

# %%
Aust_df = data_df.loc[data_df["Country"] == "Australia", :]

Aus_df.head(5)
# Out:
#      Country  Year  \
# 389  Austria  1961
# 390  Austria  1962
# 391  Austria  1963
# 392  Austria  1964
# 393  Austria  1965
#
#      Fertilizer consumption (kilograms per hectare of arable land)
# 389                                         148.908829
# 390                                         172.626419
# 391                                         196.862320
# 392                                         209.095963
# 393                                         218.843368

# %%
Aust_df.plot.line(x='Year', y='Fertilizer consumption (kilograms per hectare of arable land)', color="blue", label="kg/ha",
                    title= "Fertilizer consumption in Australia");
plt.xlabel("Years");
plt.ylabel("kg/ha of arable land");

plt.savefig("../static/Images/Fertilizer consumption in Australia.png")

# %%
Neth_df = data_df.loc[data_df["Country"] == "Netherlands", :]

Neth_df.head(5)
# Out:
#           Country  Year  \
# 5604  Netherlands  1961
# 5605  Netherlands  1962
# 5606  Netherlands  1963
# 5607  Netherlands  1964
# 5608  Netherlands  1965
#
#       Fertilizer consumption (kilograms per hectare of arable land)
# 5604                                         473.891144
# 5605                                         538.159424
# 5606                                         587.039002
# 5607                                         580.547485
# 5608                                         605.842651

# %%
Neth_df.plot.line(x='Year', y='Fertilizer consumption (kilograms per hectare of arable land)', color="green", label="kg/ha",
                    title= "Fertilizer consumption in Netherlands");
plt.xlabel("Years");
plt.ylabel("kg/ha of arable land");

plt.savefig("../static/Images/Fertilizer consumption in Netherlands.png")

# %%
China_df = data_df.loc[data_df["Country"] == "China", :]

China_df.head(5)
# Out:
#      Country  Year  \
# 1620   China  1961
# 1621   China  1962
# 1622   China  1963
# 1623   China  1964
# 1624   China  1965
#
#       Fertilizer consumption (kilograms per hectare of arable land)
# 1620                                           7.040823
# 1621                                           9.598448
# 1622                                          12.118209
# 1623                                          16.328320
# 1624                                          25.415293

# %%
China_df.plot.line(x='Year', y='Fertilizer consumption (kilograms per hectare of arable land)', color="brown", label="kg/ha",
                    title= "Fertilizer consumption in China");
plt.xlabel("Years");
plt.ylabel("kg/ha of arable land");

plt.savefig("../static/Images/Fertilizer consumption in China.png")

# %%
Belg_df = data_df.loc[data_df["Country"] == "Belgium", :]

Belg_df.head(5)
# Out:
#      Country  Year  \
# 704  Belgium  1961
# 705  Belgium  1962
# 706  Belgium  1963
# 707  Belgium  1964
# 708  Belgium  1965
#
#      Fertilizer consumption (kilograms per hectare of arable land)
# 704                                         384.615692
# 705                                         462.515930
# 706                                         479.240753
# 707                                         431.865723
# 708                                         467.246979

# %%
Belg_df.plot.line(x='Year', y='Fertilizer consumption (kilograms per hectare of arable land)', color="red", label="kg/ha",
                    title= "Fertilizer consumption in Belgium");
plt.xlabel("Years");
plt.ylabel("kg/ha of arable land");

plt.savefig("../static/Images/Fertilizer consumption in Belgium.png")

# %%
Spn_df = data_df.loc[data_df["Country"] == "Spain", :]

Spn_df.head(5)
# Out:
#      Country  Year  \
# 7335   Spain  1961
# 7336   Spain  1962
# 7337   Spain  1963
# 7338   Spain  1964
# 7339   Spain  1965
#
#       Fertilizer consumption (kilograms per hectare of arable land)
# 7335                                          44.925274
# 7336                                          46.157707
# 7337                                          46.058006
# 7338                                          48.191406
# 7339                                          49.001564

# %%
Spn_df.plot.line(x='Year', y='Fertilizer consumption (kilograms per hectare of arable land)', color="purple", label="kg/ha",
                    title= "Fertilizer consumption in Spain");
plt.xlabel("Years");
plt.ylabel("kg/ha of arable land");

plt.savefig("../static/Images/Fertilizer consumption in Spain.png")

# %%
UK_df = data_df.loc[data_df["Country"] == "United Kingdom", :]

UK_df.head(5)
# Out:
#              Country  Year  \
# 8263  United Kingdom  1961
# 8264  United Kingdom  1962
# 8265  United Kingdom  1963
# 8266  United Kingdom  1964
# 8267  United Kingdom  1965
#
#       Fertilizer consumption (kilograms per hectare of arable land)
# 8263                                         195.289200
# 8264                                         195.080154
# 8265                                         205.525772
# 8266                                         203.154739
# 8267                                         211.827225

# %%
UK_df.plot.line(x='Year', y='Fertilizer consumption (kilograms per hectare of arable land)', color="black", label="kg/ha",
                    title= "Fertilizer consumption in UK");
plt.xlabel("Years");
plt.ylabel("kg/ha of arable land");

plt.savefig("../static/Images/Fertilizer consumption in UK.png")

# %%
US_df = data_df.loc[data_df["Country"] == "United States", :]

US_df.head(5)
# Out:
#             Country  Year  \
# 8321  United States  1961
# 8322  United States  1962
# 8323  United States  1963
# 8324  United States  1964
# 8325  United States  1965
#
#       Fertilizer consumption (kilograms per hectare of arable land)
# 8321                                          41.334278
# 8322                                          46.725536
# 8323                                          51.064835
# 8324                                          55.029480
# 8325                                          61.038200

# %%
US_df.plot.line(x='Year', y='Fertilizer consumption (kilograms per hectare of arable land)', color="orange", label="kg/ha",
                    title= "Fertilizer consumption in US");
plt.xlabel("Years");
plt.ylabel("kg/ha of arable land");

plt.savefig("../static/Images/Fertilizer consumption in US.png")

# %%
Aus_df = data_df.loc[data_df["Country"] == "Austria", :]

Aus_df.head(5)
# Out:
#      Country  Year  \
# 389  Austria  1961
# 390  Austria  1962
# 391  Austria  1963
# 392  Austria  1964
# 393  Austria  1965
#
#      Fertilizer consumption (kilograms per hectare of arable land)
# 389                                         148.908829
# 390                                         172.626419
# 391                                         196.862320
# 392                                         209.095963
# 393                                         218.843368

# %%
Aus_df.plot.line(x='Year', y='Fertilizer consumption (kilograms per hectare of arable land)', color="cyan", label="kg/ha",
                    title= "Fertilizer consumption in Austria");
plt.xlabel("Years");
plt.ylabel("kg/ha of arable land");

plt.savefig("../static/Images/Fertilizer consumption in Austria.png")

# %%
Ger_df = data_df.loc[data_df["Country"] == "Germany", :]

Ger_df.head(5)
# Out:
#       Country  Year  \
# 3025  Germany  1961
# 3026  Germany  1962
# 3027  Germany  1963
# 3028  Germany  1964
# 3029  Germany  1965
#
#       Fertilizer consumption (kilograms per hectare of arable land)
# 3025                                         268.068726
# 3026                                         291.786957
# 3027                                         304.436401
# 3028                                         324.976166
# 3029                                         345.248261

# %%
Ger_df.plot.line(x='Year', y='Fertilizer consumption (kilograms per hectare of arable land)', color="darkred", label="kg/ha",
                    title= "Fertilizer consumption in Germany");
plt.xlabel("Years");
plt.ylabel("kg/ha of arable land");

plt.savefig("../static/Images/Fertilizer consumption in Germany.png")

# %%
Mex_df = data_df.loc[data_df["Country"] == "Mexico", :]

Mex_df.head(5)
# Out:
#      Country  Year  \
# 5098  Mexico  1961
# 5099  Mexico  1962
# 5100  Mexico  1963
# 5101  Mexico  1964
# 5102  Mexico  1965
#
#       Fertilizer consumption (kilograms per hectare of arable land)
# 5098                                           9.791357
# 5099                                          10.527405
# 5100                                          14.485981
# 5101                                          15.023879
# 5102                                          17.638010

# %%
Mex_df.plot.line(x='Year', y='Fertilizer consumption (kilograms per hectare of arable land)', color="peachpuff", label="kg/ha",
                    title= "Fertilizer consumption in Mexico");
plt.xlabel("Years");
plt.ylabel("kg/ha of arable land");

plt.savefig("../static/Images/Fertilizer consumption in Mexico.png")

# %%
plt.figure(facecolor='gray')
ax = plt.axes()
ax.set_facecolor("lightgray")


plt.rcParams["figure.figsize"] = (14, 10)
plt.plot(Aust_df['Year'], Aust_df['Fertilizer consumption (kilograms per hectare of arable land)'])
plt.plot(Neth_df['Year'], Neth_df['Fertilizer consumption (kilograms per hectare of arable land)'])
plt.plot(Belg_df['Year'], Belg_df['Fertilizer consumption (kilograms per hectare of arable land)'])
plt.plot(Spn_df['Year'], Spn_df['Fertilizer consumption (kilograms per hectare of arable land)'])
plt.plot(China_df['Year'], China_df['Fertilizer consumption (kilograms per hectare of arable land)']);
plt.plot(UK_df['Year'],UK_df['Fertilizer consumption (kilograms per hectare of arable land)'])
plt.plot(US_df['Year'],US_df['Fertilizer consumption (kilograms per hectare of arable land)'])
plt.plot(Aus_df['Year'],Aus_df['Fertilizer consumption (kilograms per hectare of arable land)'])
plt.plot(Ger_df['Year'],Ger_df['Fertilizer consumption (kilograms per hectare of arable land)'])
plt.plot(Mex_df['Year'],Mex_df['Fertilizer consumption (kilograms per hectare of arable land)'])

plt.xlabel("Years");
plt.ylabel("kg/ha of arable land)");
plt.title("World Fertilizer Consumption Top Consumer");

labels = ['Australia','Netherlands','Belgium','Spain','China','UK','US','Austria','Germany','Mexico']
plt.legend(labels,loc="best");

plt.savefig("../static/Images/World Fertilizer Consumption.png")

# %%
fig, axs = plt.subplots(2, 5, sharex='all')

fig.suptitle("Top 10 Fertilizer Cunsumer in the World")

years =[1990,2000,2010,2020]

axs[0, 0].plot(Neth_df['Year'], Neth_df['Fertilizer consumption (kilograms per hectare of arable land)'])
axs[0, 0].set_title("Netherlands")

axs[1, 0].plot(Belg_df['Year'], Belg_df['Fertilizer consumption (kilograms per hectare of arable land)'])
axs[1, 0].set_title("Belgium")

axs[0, 1].plot(Spn_df['Year'], Spn_df['Fertilizer consumption (kilograms per hectare of arable land)'])
axs[0, 1].set_title("Spain")

axs[1, 1].plot(China_df['Year'], China_df['Fertilizer consumption (kilograms per hectare of arable land)'])
axs[1, 1].set_title("China")

axs[0, 2].plot(UK_df['Year'], UK_df['Fertilizer consumption (kilograms per hectare of arable land)'])
axs[0, 2].set_title("UK")

axs[1, 2].plot(US_df['Year'], US_df['Fertilizer consumption (kilograms per hectare of arable land)'])
axs[1, 2].set_title("US")

axs[0, 3].plot(Aus_df['Year'], Aus_df['Fertilizer consumption (kilograms per hectare of arable land)'])
axs[0, 3].set_title("Austria")

axs[1, 3].plot(Ger_df['Year'], Ger_df['Fertilizer consumption (kilograms per hectare of arable land)'])
axs[1, 3].set_title("Germany")

axs[0, 4].plot(Aust_df['Year'], Aust_df['Fertilizer consumption (kilograms per hectare of arable land)'])
axs[0, 4].set_title("Australia")

axs[1, 4].plot(Mex_df['Year'], Mex_df['Fertilizer consumption (kilograms per hectare of arable land)'])
axs[1, 4].set_title("Mexico")


axs[0,0].tick_params(labelbottom=True)
axs[0,1].tick_params(labelbottom=True)
axs[0,2].tick_params(labelbottom=True)
axs[1,2].tick_params(labelbottom=True)
axs[0,3].tick_params(labelbottom=True)
axs[1,3].tick_params(labelbottom=True)
axs[0,4].tick_params(labelbottom=True)
axs[1,4].tick_params(labelbottom=True)

plt.savefig("../static/Images/Top 10 Fertilizer Cunsumer in the World.png")

fig.tight_layout()
